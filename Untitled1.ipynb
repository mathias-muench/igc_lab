# %%
#!/usr/bin/env python
# coding: utf-8


import glob
from igc_lib.igc_lib import Flight
import pdflight
from joblib import Parallel, delayed


flights = Parallel(n_jobs=-1)(
    delayed(Flight.create_from_file)(i) for i in glob.glob("igc_files/777_SP.igc")
)


(md, fl, th) = pdflight.flights_to_dataframes(flight for flight in flights if flight.valid)

# %%
fl.loc[pdflight.in_task(fl, md)]

# %%
th
